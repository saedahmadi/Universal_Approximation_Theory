# %% [markdown]
# <a href="https://colab.research.google.com/github/saedahmadi/Universal_Approximation_Theory/blob/main/Universal_Approximation_Theory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np

# تعریف تابع f(x)
def f(x):
  return (x**3) + (x**2) - (x) - 1

# بررسی شکل ورودی و در صورت نیاز تغییر شکل آن
def prepare_input(x):
  if tf.shape(x)[0] == 1:
    x_reshaped = tf.reshape(x, [-2, 2])
  else:
    x_reshaped = x
  return x_reshaped



# تعریف مدل شبکه عصبی
model = tf.keras.Sequential([
  tf.keras.layers.Dense(10, activation='relu', input_shape=(None, 1)),  # لایه اول با 10 گره و فعال سازی ReLU
  tf.keras.layers.Dense(1)  # لایه خروجی با 1 گره
])

# کامپایل مدل
model.compile(optimizer='adam', loss='mse')

# داده های آموزشی
x_train = np.linspace(-2, 2, 100)  # 100 نقطه داده در بازه [-2, 2]
y_train = f(x_train)

# تبدیل داده های آموزشی به شکل مناسب - Moved after x_train is defined
x_train_prepared = prepare_input(x_train)
y_train_prepared = f(x_train_prepared) # This line might be unnecessary now

# آموزش مدل - Use the prepared data
model.fit(x_train_prepared, y_train_prepared, epochs=1000)  # آموزش مدل برای 1000 دوره

# پیش بینی مقادیر برای ورودی های جدید
x_new = np.array([-1.5, 0.5, 1.8])
# Prepare the new input as well
x_new_prepared = prepare_input(x_new)
y_pred = model.predict(x_new_prepared)

# نمایش نتایج
print("f(-1.5) = ", y_pred[0])
print("f(0.5)  = ", y_pred[1])
print("f(1.8)  = ", y_pred[2])
# Out:
# Epoch 1/1000
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-42bfc8429a2a> in <cell line: 36>()
#      34
#      35 # آموزش مدل - Use the prepared data
# ---> 36 model.fit(x_train_prepared, y_train_prepared, epochs=1000)  # آموزش مدل برای 1000 دوره
#      37
#      38 # پیش بینی مقادیر برای ورودی های جدید
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in tf__train_function(iterator)
#      13                 try:
#      14                     do_return = True
# ...

# %%
import tensorflow as tf
import numpy as np

# تعریف تابع f(x)
def f(x):
  return (x**3) + (x**2) - (x) - 1

# بررسی شکل ورودی و در صورت نیاز تغییر شکل آن
def prepare_input(x):
  # Reshape to (number of samples, 1) regardless of input shape
  x_reshaped = tf.reshape(x, [-1, 1])
  return x_reshaped



# تعریف مدل شبکه عصبی
model = tf.keras.Sequential([
  tf.keras.layers.Dense(10, activation='relu', input_shape=(1,)),  # لایه اول با 10 گره و فعال سازی ReLU, note the input shape
  tf.keras.layers.Dense(1)  # لایه خروجی با 1 گره
])

# کامپایل مدل
model.compile(optimizer='adam', loss='mse')

# داده های آموزشی
x_train = np.linspace(-2, 2, 100)  # 100 نقطه داده در بازه [-2, 2]
y_train = f(x_train)

# تبدیل داده های آموزشی به شکل مناسب - Moved after x_train is defined
x_train_prepared = prepare_input(x_train)
# y_train_prepared = f(x_train_prepared) # No need to recalculate y_train

# آموزش مدل - Use the prepared data
model.fit(x_train_prepared, y_train, epochs=1000)  # آموزش مدل برای 1000 دوره

# پیش بینی مقادیر برای ورودی های جدید
x_new = np.array([-1.5, 0.5, 1.8])
# Prepare the new input as well
x_new_prepared = prepare_input(x_new)
y_pred = model.predict(x_new_prepared)

# نمایش نتایج
print("f(-1.5) = ", y_pred[0], "original f(x)= ", f(-1.5))
print("f(0.5)  = ", y_pred[1], "original f(x)= ",f(0.5))
print("f(1.8)  = ", y_pred[2], "original f(x)= ",f(1.8))
# Out:
# Epoch 1/1000
# 4/4 [==============================] - 1s 21ms/step - loss: 5.1577
# Epoch 2/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 5.1022
# Epoch 3/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 5.0439
# Epoch 4/1000
# 4/4 [==============================] - 0s 10ms/step - loss: 4.9887
# Epoch 5/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 4.9375
# Epoch 6/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 4.8872
# Epoch 7/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 4.8334
# Epoch 8/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 4.7868
# Epoch 9/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 4.7398
# Epoch 10/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 4.6945
# Epoch 11/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 4.6493
# Epoch 12/1000
# ...

# %%
import tensorflow as tf
import numpy as np

# تعریف تابع f(x)
def f(x):
  return (x**3) + (x**2) - (x) - 1

# بررسی شکل ورودی و در صورت نیاز تغییر شکل آن
def prepare_input(x):
  # Reshape to (number of samples, 1) regardless of input shape
  x_reshaped = tf.reshape(x, [-1, 1])
  return x_reshaped



# تعریف مدل شبکه عصبی
model = tf.keras.Sequential([
  tf.keras.layers.Dense(100, activation='relu', input_shape=(1,)),  # لایه اول با 100 گره و فعال سازی ReLU, note the input shape
  tf.keras.layers.Dense(1)  # لایه خروجی با 1 گره
])

# کامپایل مدل
model.compile(optimizer='adam', loss='mse')

# داده های آموزشی
x_train = np.linspace(-2, 2, 100)  # 100 نقطه داده در بازه [-2, 2]
y_train = f(x_train)

# تبدیل داده های آموزشی به شکل مناسب - Moved after x_train is defined
x_train_prepared = prepare_input(x_train)
# y_train_prepared = f(x_train_prepared) # No need to recalculate y_train

# آموزش مدل - Use the prepared data
model.fit(x_train_prepared, y_train, epochs=1000)  # آموزش مدل برای 1000 دوره

# پیش بینی مقادیر برای ورودی های جدید
x_new = np.array([-1.5, 0.5, 1.8])
# Prepare the new input as well
x_new_prepared = prepare_input(x_new)
y_pred = model.predict(x_new_prepared)

# نمایش نتایج
print("f(-1.5) = ", y_pred[0], "original f(x)= ", f(-1.5))
print("f(0.5)  = ", y_pred[1], "original f(x)= ",f(0.5))
print("f(1.8)  = ", y_pred[2], "original f(x)= ",f(1.8))
# Out:
# Epoch 1/1000
# 4/4 [==============================] - 1s 5ms/step - loss: 6.2435
# Epoch 2/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 6.0191
# Epoch 3/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 5.8068
# Epoch 4/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 5.6142
# Epoch 5/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 5.4629
# Epoch 6/1000
# 4/4 [==============================] - 0s 7ms/step - loss: 5.3026
# Epoch 7/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 5.1567
# Epoch 8/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 5.0231
# Epoch 9/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 4.8971
# Epoch 10/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 4.7645
# Epoch 11/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 4.6235
# Epoch 12/1000
# 4/4 [==============================] - 0s 4ms/step - loss: 4.5035
# ...

# %%
import tensorflow as tf
import numpy as np

# تعریف تابع f(x)
def f(x):
  return (x**3) + (x**2) - (x) - 1

# بررسی شکل ورودی و در صورت نیاز تغییر شکل آن
def prepare_input(x):
  # Reshape to (number of samples, 1) regardless of input shape
  x_reshaped = tf.reshape(x, [-1, 1])
  return x_reshaped



# تعریف مدل شبکه عصبی
model = tf.keras.Sequential([
  tf.keras.layers.Dense(100, activation='relu', input_shape=(1,)),  # لایه اول با 10 گره و فعال سازی ReLU, note the input shape
  tf.keras.layers.Dense(1)  # لایه خروجی با 1 گره
])

# کامپایل مدل
model.compile(optimizer='adam', loss='mse')

# داده های آموزشی
x_train = np.linspace(-2, 2, 100)  # 100 نقطه داده در بازه [-2, 2]
y_train = f(x_train)

# تبدیل داده های آموزشی به شکل مناسب - Moved after x_train is defined
x_train_prepared = prepare_input(x_train)
# y_train_prepared = f(x_train_prepared) # No need to recalculate y_train

# آموزش مدل - Use the prepared data
model.fit(x_train_prepared, y_train, epochs=1000)  # آموزش مدل برای 1000 دوره

# پیش بینی مقادیر برای ورودی های جدید
x_new = np.array([-1.5, 0.5, 1.8])
# Prepare the new input as well
x_new_prepared = prepare_input(x_new)
y_pred = model.predict(x_new_prepared)

# نمایش نتایج
print("f(-1.5) = ", y_pred[0], "original f(x)= ", f(-1.5))
print("f(0.5)  = ", y_pred[1], "original f(x)= ",f(0.5))
print("f(1.8)  = ", y_pred[2], "original f(x)= ",f(1.8))
# Out:
# Epoch 1/1000
# 4/4 [==============================] - 1s 7ms/step - loss: 5.1775
# Epoch 2/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 4.9913
# Epoch 3/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 4.8277
# Epoch 4/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 4.6771
# Epoch 5/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 4.5365
# Epoch 6/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 4.4058
# Epoch 7/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 4.2996
# Epoch 8/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 4.1860
# Epoch 9/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 4.0915
# Epoch 10/1000
# 4/4 [==============================] - 0s 6ms/step - loss: 3.9791
# Epoch 11/1000
# 4/4 [==============================] - 0s 5ms/step - loss: 3.9038
# Epoch 12/1000
# 4/4 [==============================] - 0s 8ms/step - loss: 3.8143
# ...

# %%
import tensorflow as tf
import numpy as np

# تعریف تابع f(x)
def f(x):
  return (x**3) + (x**2) - (x) - 1

# بررسی شکل ورودی و در صورت نیاز تغییر شکل آن
def prepare_input(x):
  # Reshape to (number of samples, 1) regardless of input shape
  x_reshaped = tf.reshape(x, [-1, 1])
  return x_reshaped



# تعریف مدل شبکه عصبی
model = tf.keras.Sequential([
  tf.keras.layers.Dense(10, activation='relu', input_shape=(1,)),  # لایه اول با 10 گره و فعال سازی ReLU, note the input shape
  tf.keras.layers.Dense(1)  # لایه خروجی با 1 گره
])

# کامپایل مدل
model.compile(optimizer='adam', loss='mse')

# داده های آموزشی
x_train = np.linspace(-2, 2, 100)  # 100 نقطه داده در بازه [-2, 2]
y_train = f(x_train)

# تبدیل داده های آموزشی به شکل مناسب - Moved after x_train is defined
x_train_prepared = prepare_input(x_train)
# y_train_prepared = f(x_train_prepared) # No need to recalculate y_train

# آموزش مدل - Use the prepared data
model.fit(x_train_prepared, y_train, epochs=10000)  # آموزش مدل برای 10000 دوره

# پیش بینی مقادیر برای ورودی های جدید
x_new = np.array([-1.5, 0.5, 1.8])
# Prepare the new input as well
x_new_prepared = prepare_input(x_new)
y_pred = model.predict(x_new_prepared)

# نمایش نتایج
print("f(-1.5) = ", y_pred[0], "original f(x)= ", f(-1.5))
print("f(0.5)  = ", y_pred[1], "original f(x)= ",f(0.5))
print("f(1.8)  = ", y_pred[2], "original f(x)= ",f(1.8))
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch 7503/10000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2953
# Epoch 7504/10000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2951
# Epoch 7505/10000
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2952
# Epoch 7506/10000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2951
# Epoch 7507/10000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2950
# Epoch 7508/10000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2949
# Epoch 7509/10000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2949
# Epoch 7510/10000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2950
# Epoch 7511/10000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2951
# Epoch 7512/10000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2952
# Epoch 7513/10000
# ...
